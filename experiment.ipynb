# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import joblib as jb
import seaborn as sns
# Out:
# c:\Users\hp\anaconda3\envs\data_science\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data_hour = pd.read_csv("hour.csv")

# %%
from keras.models import load_model
model_1 = load_model("model.h5")

# %%
model_1.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 12)                156
#
#  dense_25 (Dense)            (None, 12)                156
#
#  dense_26 (Dense)            (None, 6)                 78
#
#  dense_27 (Dense)            (None, 1)                 7
#
# ...
# Total params: 397
# Trainable params: 397
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
# Load and preprocess the data

data_hour = pd.read_csv('hour.csv')
train_x, test_x, train_y , test_y = train_test_split(data_hour[['season', 'yr', 'mnth',  'holiday', 'weekday', 'workingday',
       'weathersit', 'temp', 'atemp', 'hum', 'windspeed']], data_hour[['cnt']],train_size=.9, random_state=42)
scaler = StandardScaler()

#x = scaler.fit_transform(train_x)
#y = scaler.fit_transform(train_y)

# %%
from keras.models import Sequential
from keras.layers import Dense
# define base model
def baseline_model():
	# create model
	model = Sequential()
	model.add(Dense(11, input_shape=(11,), kernel_initializer='normal', activation='relu'))
	model.add(Dense(11, input_shape=(11,), kernel_initializer='normal', activation='relu'))
	
	model.add(Dense(1, kernel_initializer='normal'))
	# Compile model
	model.compile(loss='mean_squared_error', optimizer='adam')
	return model

# %%
model = baseline_model()
model.fit(train_x, train_y,epochs=100)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 1s 2ms/step - loss: 23902918.0000
# Epoch 2/100
# 21/21 [==============================] - 0s 2ms/step - loss: 23902304.0000
# Epoch 3/100
# 21/21 [==============================] - 0s 2ms/step - loss: 23900320.0000
# Epoch 4/100
# 21/21 [==============================] - 0s 2ms/step - loss: 23894730.0000
# Epoch 5/100
# 21/21 [==============================] - 0s 2ms/step - loss: 23882368.0000
# Epoch 6/100
# 21/21 [==============================] - 0s 3ms/step - loss: 23859358.0000
# Epoch 7/100
# 21/21 [==============================] - 0s 2ms/step - loss: 23820714.0000
# Epoch 8/100
# 21/21 [==============================] - 0s 3ms/step - loss: 23763652.0000
# Epoch 9/100
# 21/21 [==============================] - 0s 3ms/step - loss: 23682328.0000
# Epoch 10/100
# 21/21 [==============================] - 0s 3ms/step - loss: 23574342.0000
# Epoch 11/100
# ...

# %%
new_model = keras.lo

# %%
model.save("model_day.h5")

# %%
from keras.models import load_model
model_1 = load_model("model.h5")
print(model_1.summary())
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 12)                156
#
#  dense_25 (Dense)            (None, 12)                156
#
#  dense_26 (Dense)            (None, 6)                 78
#
#  dense_27 (Dense)            (None, 1)                 7
#
# ...
# Total params: 397
# Trainable params: 397
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
X = data_hour[['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
       'weathersit', 'temp', 'atemp', 'hum', 'windspeed']]
y_pred = model_1.predict(X)
# Out:
# 544/544 [==============================] - 1s 2ms/step

# %%
print(r2_score(y_pred, data_hour['cnt']))
# Out:
# 0.6341700863027441

# %%
scaler =  StandardScaler()
x = scaler.fit_transform(test_x)
y = scaler.fit_transform(test_y)

y_pred = model.predict(x)
# Out:
# 109/109 [==============================] - 0s 1ms/step

# %%
print(r2_score(y_pred, test_y))
# Out:
# -187045.60943163425

# %%
# working with deep learninng mod
from keras.models import Sequential
from keras.layers import Dense , Dropout
new_model =  Sequential()
new_model.layers = (
    Dense(1, activation="tankh")
)

# %%
data_hour.shape
# Out:
# (17379, 17)

# %%
data_hour.head(5)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
x =data_hour.groupby(['yr']).sum()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19460\564724116.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   x =data_hour.groupby(['yr']).sum()

# %%
x
# Out:
#       instant  season   mnth      hr  holiday  weekday  workingday  \
# yr
# 0    37372335   21730  56832  100054      239    26045        5911
# 1   113651175   21746  56788  100617      261    26156        5954
#
#     weathersit     temp      atemp      hum  windspeed  casual  registered  \
# yr
# 0        12428  4228.00  4054.5089  5562.45  1652.6842  247252      995851
# 1        12342  4409.14  4213.9866  5338.16  1651.0221  372765     1676811
#
#         cnt
# yr
# 0   1243103
# 1   2049576

# %%
x['cnt'].plot.bar()
# Out:
# <AxesSubplot: xlabel='yr'>

# %%
data_hour.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
data_hour['dteday'] = pd.to_datetime(data_hour['dteday'])

# %%
data_hour.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
str(data_hour.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB
# 'None'

# %%
def get_dataframe_day():
    data = pd.read_csv("day.csv")
    data_info = pd.DataFrame(data.info())
    
    
    return [data, data_info]

get_dataframe_day()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# ...

# %%
data_hour.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
data_hour.index = data_hour['dteday'] # ignore error

# %%
sns.heatmap(data_hour[['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
       'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
       'casual', 'registered', 'cnt']].corr())
# Out:
# <AxesSubplot: >

# %%
# plotting data
plt.plot(data_hour['cnt'])

# %%
data_hour.describe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data_hour.describe
#
# NameError: name 'data_hour' is not defined

# %%
data_hour.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
# 5        6  2011-01-01       1   0     1   5        0        6           0
# 6        7  2011-01-01       1   0     1   6        0        6           0
# 7        8  2011-01-01       1   0     1   7        0        6           0
# 8        9  2011-01-01       1   0     1   8        0        6           0
# 9       10  2011-01-01       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# ...

# %%
data_hour.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
data_hour.drop(['instant', 'dteday', 'casual', 'registered'], axis = 1, inplace = True)

# %%
data_hour.head(10)
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0       1   0     1   0        0        6           0           1  0.24
# 1       1   0     1   1        0        6           0           1  0.22
# 2       1   0     1   2        0        6           0           1  0.22
# 3       1   0     1   3        0        6           0           1  0.24
# 4       1   0     1   4        0        6           0           1  0.24
# 5       1   0     1   5        0        6           0           2  0.24
# 6       1   0     1   6        0        6           0           1  0.22
# 7       1   0     1   7        0        6           0           1  0.20
# 8       1   0     1   8        0        6           0           1  0.24
# 9       1   0     1   9        0        6           0           1  0.32
#
#     atemp   hum  windspeed  cnt
# 0  0.2879  0.81     0.0000   16
# 1  0.2727  0.80     0.0000   40
# 2  0.2727  0.80     0.0000   32
# 3  0.2879  0.75     0.0000   13
# ...

# %% [markdown]
# <h1> model building </h1>

# %%
import seaborn as sns 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

# %%
data_hour.columns
# Out:
# Index(['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt'],
#       dtype='object')

# %%
train_x, test_x, train_y , test_y = train_test_split(data_hour[['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
       'weathersit', 'temp', 'atemp', 'hum', 'windspeed']], data_hour['cnt'], random_state=42)

# %%
# normalizing data
normalize  = StandardScaler()

train_x = normalize.fit_transform(train_x)
test_x = normalize.fit_transform(test_x)

# %%
model_1 = LinearRegression()
model_1.fit(train_x, train_y)
y_pred = model_1.predict(test_x)
print(r2_score(test_y, y_pred))
# Out:
# 0.3831521892256272

# %%
model_2 = RandomForestRegressor()
model_2.fit(train_x, train_y)
y_pred = model_2.predict(test_x)
print(r2_score(test_y, y_pred))
# Out:
# 0.9433251820104844

# %%
model_3 = SVR(kernel="linear")
model_3.fit(train_x, train_y)
y_pred = model_3.predict(test_x)
print(r2_score(test_y, y_pred))
# Out:
# 0.3411264504811391

# %%
# using decesion - tree
model_4 = DecisionTreeRegressor()
model_4.fit(train_x, train_y)
y_pred = model_4.predict(test_x)
print(r2_score(test_y, y_pred))
# Out:
# 0.8873613013324142

# %% [markdown]
# <h1> for daily - bike prediction </h1>

# %%
data_daily  = pd.read_csv("day.csv")
data_daily.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
# 5        6  2011-01-06       1   0     1        0        4           1
# 6        7  2011-01-07       1   0     1        0        5           1
# 7        8  2011-01-08       1   0     1        0        6           0
# 8        9  2011-01-09       1   0     1        0        0           0
# 9       10  2011-01-10       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# ...

# %%
data_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
data_daily['dteday'] = pd.to_datetime(data_daily['dteday'])

# %%
data_daily.index = data_daily['dteday']

# %%
plt.plot(data_daily['cnt'])

# %%
data_daily.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
train_x, test_x, train_y , test_y = train_test_split(data_daily[['season', 'yr', 'mnth',  'holiday', 'weekday', 'workingday',
       'weathersit', 'temp', 'atemp', 'hum', 'windspeed']], data_daily['cnt'], random_state=42)

# %%
model_2 = RandomForestRegressor()
model_2.fit(train_x, train_y)
y_pred = model_2.predict(test_x)
print(r2_score(test_y, y_pred))
# Out:
# 0.8917811214858878
